# %% [markdown]
# # Ian Redan
# Notebook for assignment 7

# %%
def compute_mean(list_values):
    return sum(list_values) / len(list_values)


compute_mean([2,4,6,8])
# Out:
# 5.0

# %% [markdown]
# $\Huge
# \bar{x} =
# \frac{x_{1} + x_{2} + ... + x_{n}}{n} =
# \frac{1}{n}
# \left( \displaystyle\sum_{i=1}^{n} x_{i}\right) $
#
# Instructions for displaying final index and summation index above and below sum from https://latex-tutorial.com/sum-latex/
#
# Instructions for increasing size of equation from https://www.cmor-faculty.rice.edu/~heinken/latex/symbols.pdf
#
# Additional instructions from assignment on LaTeX:
# - https://davidhamann.de/2017/06/12/latex-cheat-sheet/
# - https://en.wikipedia.org/wiki/Summation#Capital-sigma_notation
# - https://latex-tutorial.com/sum-latex/
